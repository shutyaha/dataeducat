# %%
print("Hello")
# Out:
# Hello

# %%
m, n = int(input()), int(input())

for i in range(m, n):
    if i % 10 == 9:
        print(i)
    elif i % 17 == 0:
        print(i)
    elif i % 15 == 0:
        print(i)
# Out:
# 17
