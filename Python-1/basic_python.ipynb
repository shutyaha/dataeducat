# %%
# !python --version
# Out:
# Python 3.12.5

# %%
print("Hello, world!")
print("Hello", "world!")
print("Hello" + "world!")
# Out:
# Hello, world!
# Hello world!
# Helloworld!

# %%
name, surname = "John", "Lennon"
print(name, surname)

name, surname = surname, name
print(name, surname)
# Out:
# John Lennon
# Lennon John
